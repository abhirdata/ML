# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ed=pd.read_csv("C:\\Users\\rabhi\\OneDrive\\Documents\\Explo_Dataset.csv")

# %%
sns.countplot(x=ed['industry_collaborator'])
# Out:
# <AxesSubplot:xlabel='industry_collaborator', ylabel='count'>

# %%
sns.countplot(x=ed['industry_sponsor'])
# Out:
# <AxesSubplot:xlabel='industry_sponsor', ylabel='count'>

# %%
sns.countplot(x=ed['fda_reg'])
# Out:
# <AxesSubplot:xlabel='fda_reg', ylabel='count'>

# %%
sns.countplot(x=ed['placebo_group'])
# Out:
# <AxesSubplot:xlabel='placebo_group', ylabel='count'>
