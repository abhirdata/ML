# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cc=pd.read_csv("C:\\Users\\rabhi\\OneDrive\\Documents\\creditcard.csv")

# %%
cc.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
cc.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()

# %%
objLis = cc.drop(['Class'],axis=1).select_dtypes(exclude = "object").columns

# %%
for feat in objLis:
    cc[feat] = s.fit_transform(cc[feat].to_numpy().reshape(-1,1))

# %%
cc
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0      -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1      -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2      -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3      -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4      -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.641931 -6.065842  6.099286 -6.486245 -1.459641 -3.886611 -1.956690
# 284803  1.641952 -0.374121 -0.033356  1.342145 -0.521651  0.629040  0.794446
# 284804  1.641974  0.980024 -0.182434 -2.143205 -0.393984  1.905833  2.275262
# 284805  1.641974 -0.122755  0.321250  0.463320  0.487192 -0.273836  0.468155
# 284806  1.642058 -0.272331 -0.114899  0.463866 -0.357570 -0.009089 -0.487602
#
# ...

# %%
x=cc.drop(['Class'],axis=1)
y=cc['Class']

# %%
plt.figure(figsize=(20,20))
cor=x.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(x, 0.70)
len(set(corr_features))
# Out:
# 0

# %%
cc[cc['Class']==1].count()
# Out:
# Time      492
# V1        492
# V2        492
# V3        492
# V4        492
# V5        492
# V6        492
# V7        492
# V8        492
# V9        492
# V10       492
# V11       492
# V12       492
# V13       492
# V14       492
# V15       492
# V16       492
# V17       492
# V18       492
# V19       492
# V20       492
# V21       492
# V22       492
# V23       492
# V24       492
# V25       492
# V26       492
# V27       492
# V28       492
# Amount    492
# Class     492
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression(class_weight='balanced')

# %%
from sklearn.model_selection import train_test_split

# %%
x=cc.drop(['Class'],axis=1)
y=cc['Class']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred_lr=lr.predict(x_test)
print("Predicted Class: {}".format(y_pred_lr))
# Out:
# Predicted Class: [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import classification_report,precision_score,recall_score,f1_score

# %%
recall_score(y_test,y_pred_lr,average='weighted')
# Out:
# 0.9782193977271397

# %%
f1_score(y_test,y_pred_lr,average='weighted')
# Out:
# 0.9875279577752094

# %%
precision_score(y_test,y_pred_lr,average='weighted')
# Out:
# 0.9982529527397632

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier(criterion='gini',max_depth=3,random_state=45,class_weight='balanced')

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=3, random_state=45)

# %%
y_pred_dt=dt.predict(x_test)

# %%
print("Predicted Class: {}".format(y_pred_dt))
# Out:
# Predicted Class: [0 0 0 ... 0 0 0]

# %%
recall_score(y_test,y_pred_dt,average='weighted')
# Out:
# 0.9532085717964023

# %%
from sklearn import tree
tree.plot_tree(dt.fit(x_train,y_train))
# Out:
# [Text(0.4230769230769231, 0.875, 'x[14] <= -1.968\ngini = 0.5\nsamples = 199364\nvalue = [99682.0, 99682.0]'),
#  Text(0.15384615384615385, 0.625, 'x[4] <= -0.405\ngini = 0.056\nsamples = 5505\nvalue = [2602.569, 88004.966]'),
#  Text(0.07692307692307693, 0.375, 'gini = 0.0\nsamples = 1454\nvalue = [728.279, 0.0]'),
#  Text(0.23076923076923078, 0.375, 'x[1] <= 1.017\ngini = 0.041\nsamples = 4051\nvalue = [1874.29, 88004.966]'),
#  Text(0.15384615384615385, 0.125, 'gini = 0.032\nsamples = 3260\nvalue = [1478.095, 88004.966]'),
#  Text(0.3076923076923077, 0.125, 'gini = -0.0\nsamples = 791\nvalue = [396.196, 0.0]'),
#  Text(0.6923076923076923, 0.625, 'x[4] <= 1.208\ngini = 0.192\nsamples = 193859\nvalue = [97079.431, 11677.034]'),
#  Text(0.5384615384615384, 0.375, 'x[3] <= -2.23\ngini = 0.107\nsamples = 179009\nvalue = [89652.392, 5411.309]'),
#  Text(0.46153846153846156, 0.125, 'gini = 0.499\nsamples = 2125\nvalue = [1062.365, 1139.223]'),
# ...

# %%
conda install -c anaconda py-xgboost
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import xgboost as xgb

# %%
smallest_class_count = y_train.sum()
largest_class_count = len(y_train) - smallest_class_count
spw = largest_class_count / smallest_class_count

# %%
xg=xgb.XGBClassifier(scale_pos_weight=spw)

# %%
xg.fit(x_train,y_train)
# Out:
# C:\Users\rabhi\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:24:17] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
# ...

# %%
y_pred_xg=xg.predict(x_test)

# %%
recall_score(y_test,y_pred_xg,average='weighted')
# Out:
# 0.9994967405170698

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=100)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf=rf.predict(x_test)

# %%
y_pred_rf
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
for i in range(0,len(y_pred_rf)):
    y_pred_rf[i]=int(y_pred_rf[i])

# %%
y_pred_rf
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
recall_score(y_test,y_pred_rf,average='weighted')
# Out:
# 0.9985838512224524

# %%
from sklearn.model_selection import cross_val_score

# %%
score1=cross_val_score(lr,x,y,cv=5)

# %%
score1
# Out:
# array([0.92665286, 0.98451599, 0.96627517, 0.96537982, 0.98778111])

# %%
score2=cross_val_score(dt,x,y,cv=5)

# %%
score2
# Out:
# array([0.08972648, 0.96209754, 0.96667896, 0.94002914, 0.97136637])

# %%
score3=cross_val_score(xg,x,y,cv=5)
# Out:
# C:\Users\rabhi\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:46:39] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
score3
# Out:
# array([0.66130052, 0.999526  , 0.99877109, 0.99949088, 0.99949088])

# %%
score4=cross_val_score(rf,x,y,cv=5)

# %%
score4
